# %%
** Cell type : TextWrite ** 
(Write your observations and table of errors here)

Test errors using Loss Matrix:

| Dataset | Bayes 2a | Bayes 2b | Bayes 2c |
|---------|---------------------|---------------------|---------------------|
| Dataset 2_1 | 1.2503162          | 1.25150098       | 1.24800491         |
| Dataset 2_2 | 1.24189317          | 1.23197457           |1.2633076          |


Confusion Matrices :

Dataset 1 Bayes 2a

|       | Y=1 | Y=2 | Y=3 | Y=4 |
|-------|-------|-------|-------|-------|
| Y=1 | 0.15825 | 0.05475 | 0.034 | 0.003 |
| Y=2 | 0.02425 | 0.1845 | 0.0155 | 0.02575 |
| Y=3 | 0.0215 | 0.01225 | 0.1925 | 0.02375 |
| Y=4 | 0.00375 | 0.034 | 0.0485 | 0.16375 |

Dataset 1 Bayes 2b

|       | Y=1 | Y=2 | Y=3 | Y=4 |
|-------|-------|-------|-------|-------|
| Y=1 | 0.11575 | 0.097 | 0.03625 | 0.001 |
| Y=2 | 0.01075 | 0.19775 | 0.02825 | 0.01325 |
| Y=3 | 0.01 | 0.02375 | 0.2045 | 0.01175 |
| Y=4 | 0.001 | 0.03725 | 0.0865 | 0.12525 |

Dataset 1 Bayes 2c

|       | Y=1 | Y=2 | Y=3 | Y=4 |
|-------|-------|-------|-------|-------|
| Y=1 | 0.1595 | 0.054 | 0.03375 | 0.00275 |
| Y=2 | 0.02475 | 0.1865 | 0.0145 | 0.02425 |
| Y=3 | 0.02225 | 0.01175 | 0.19325 | 0.02275 |
| Y=4 | 0.004 | 0.03525 | 0.05025 | 0.1605 |

Dataset 2 Bayes 2a

|       | Y=1 | Y=2 | Y=3 | Y=4 |
|-------|-------|-------|-------|-------|
| Y=1 | 0.2075 | 0.0375 | 0.0045 | 0.0005 |
| Y=2 | 0.02325 | 0.196 | 0.0115 | 0.01925 |
| Y=3 | 0.0075 | 0.01525 | 0.22625 | 0.001 |
| Y=4 | 0.0 | 0.00575 | 0.0195 | 0.22475 |

Dataset 2 Bayes 2b

|       | Y=1 | Y=2 | Y=3 | Y=4 |
|-------|-------|-------|-------|-------|
| Y=1 | 0.16875 | 0.0755 | 0.00575 | 0.0 |
| Y=2 | 0.00975 | 0.18725 | 0.05125 | 0.00175 |
| Y=3 | 0.00175 | 0.0295 | 0.21875 | 0.0 |
| Y=4 | 0.0 | 0.00075 | 0.07425 | 0.175 |

Dataset 2 Bayes 2c

|       | Y=1 | Y=2 | Y=3 | Y=4 |
|-------|-------|-------|-------|-------|
| Y=1 | 0.239 | 0.008 | 0.003 | 0.0 |
| Y=2 | 0.036 | 0.184 | 0.01175 | 0.01825 |
| Y=3 | 0.00675 | 0.00725 | 0.23375 | 0.00225 |
| Y=4 | 0.0 | 0.008 | 0.013 | 0.229 |



Observations : 

1: The training and test datasets for Datasets 2_1 and 2_2 have been plotted above. It can be observed that the decision boundaries are given clearly when the learned classifiers are plotted

2: The dataset have mixing of data , ie. there is no distinct decision boundary but the learned classifiers do , and thus there is some inherent error in the learned classifiers

3: For dataset 1 ,  all 3 classifiers give nearly same error with Bayes 2c giving the least error since it assumes different mean and covariance for all 4 classes of Y. 

4: For dataset 2 , Bayes 2b gives the least error of the 3 datasets.

# %%
** Cell type : TextWrite ** 
(Write your observations and table of errors here)

The following are the Test error values of the bayes classifiers on the corresponding datasets

Test Error values


| Dataset | Bayes 1a | Bayes 1b | Bayes 1c |
|---------|---------------------|---------------------|---------------------|
| Dataset 1_1 | 0.126          | 0.1245       | 0.1245          |
| Dataset 1_2 | 0.085          | 0.0000           | 0.0000           |
| Dataset 1_3 | 0.497           | 0.495           | 0.135         |


The test error values have been given in the table above for all 3 datasets and the 3 classifiers

Observations :-

1:  Bayes 1a classifer is observed to have the highest error rate in all 3 datasets. This is because it assumes that the     covariance matrix is Identity for both P(X|Y=+1) and P(X|Y=-1) . This is a very strong assumption and it can be observed in the graph as well that the plot is quite different from the actual plot


2: Bayes 1b and Bayes 1c classifiers have the same error rate for first 2 datasets. This is because the first 2 datasets can be observed to have distinct boundaries between Y=+1 and Y=-1 points. So the assumption in Bayes 1b that both P(X|Y=+1) and P(X|Y=-1) have same covariance matrix doesn't hurt the output significantly


3: Bayes 1c classifier is the strongest among all 3 as can be seen from the plots and the test error values as well. It has the most general expression for P(X|Y=+1) and P(X|Y=-1) having different covariance matrices. This leads to it performing very well on Dataset 3 with no distinct boundary between Y=+1 and Y=-1 data points having the lowest error rate among all 3 classifiers.


4: Bayes 1a and Bayes 1b perform almost equally bad for dataset 3 where the error rate is nearly 0.5 implying that it is close to random.

5: Dataset 3 has no distinct decision boundary as can be seen from the plot as well and hence gives the highest error values among all 3 datasets.

# %% [markdown]
# Train Squared error table for Size = 50
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.2503831 | 0.25038312 | 0.25038312 | 0.25038312 | 0.25038442 | 0.25589783 |
# | 2 | 0.1341117 | 0.1341116 | 0.1341116 | 0.13411161 | 0.13417766 | 0.18145572 |
# | 4 | 0.10201813 | 0.10201831 | 0.10201831 | 0.10201835 | 0.10219687 | 0.1311145 |
# | 8 | 0.00013272 | 0.00013275 | 0.00019587 | 0.01353435 | 0.04378772 | 0.08929349 |
# | 16 | 0.0 | 0.0 | 0.0 | 2.88e-06 | 0.00077195 | 0.03271748 |
#
#
#
# Train Squared error table for Size = 100
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.2580911 | 0.25809101 | 0.25809101 | 0.25809101 | 0.25809112 | 0.25873988 |
# | 2 | 0.13095067 | 0.13095063 | 0.13095063 | 0.13095063 | 0.13096115 | 0.15450906 |
# | 4 | 0.11302653 | 0.11302663 | 0.11302664 | 0.11302664 | 0.11307242 | 0.12664842 |
# | 8 | 0.04159139 | 0.04158797 | 0.04159028 | 0.04467201 | 0.06193263 | 0.09908461 |
# | 16 | 0.0 | 0.0 | 5.2e-07 | 5.879e-05 | 0.0028642 | 0.02933147 |
#
#
#
# Train Squared error table for Size = 200
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.24653515 | 0.24653507 | 0.24653507 | 0.24653507 | 0.24653509 | 0.24664115 |
# | 2 | 0.13366532 | 0.13366533 | 0.13366533 | 0.13366533 | 0.13366724 | 0.14211695 |
# | 4 | 0.11333804 | 0.11333816 | 0.11333816 | 0.11333816 | 0.11335028 | 0.12593914 |
# | 8 | 0.06173648 | 0.06173728 | 0.06173733 | 0.06177017 | 0.06557054 | 0.09978968 |
# | 16 | 0.00373968 | 1.9e-07 | 1.79e-06 | 6.371e-05 | 0.00263314 | 0.03214762 |
#
#
#
# Train Squared error table for Size = 1000
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.24072819 | 0.24072822 | 0.24072822 | 0.24072822 | 0.24072822 | 0.24072872 |
# | 2 | 0.13882379 | 0.1388241 | 0.1388241 | 0.1388241 | 0.13882416 | 0.13926669 |
# | 4 | 0.12501646 | 0.12501723 | 0.12501724 | 0.12501724 | 0.12501746 | 0.12621395 |
# | 8 | 0.07674167 | 0.07674266 | 0.07674285 | 0.07674312 | 0.07703294 | 0.09643488 |
# | 16 | 236.34053706 | 6.649e-05 | 2.33e-06 | 4.101e-05 | 0.00120973 | 0.01872963 |
#
#
#
# Test Squared error table for Size = 50
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.3289023 | 0.32890202 | 0.32890197 | 0.32889624 | 0.32832797 | 0.29661252 |
# | 2 | 0.16148583 | 0.16148596 | 0.16148581 | 0.16147057 | 0.16010899 | 0.19983839 |
# | 4 | 0.15931203 | 0.15931153 | 0.1593109 | 0.159248 | 0.15603977 | 0.16438155 |
# | 8 | 31.28357022 | 31.6576907 | 40.13709311 | 2.90569878 | 0.29608816 | 0.16513925 |
# | 16 | 311.86311434 | 311.85156977 | 310.70270535 | 227.70096046 | 10.5299612 | 5.05617119 |
#
#
#
# Test Squared error table for Size = 100
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.32256206 | 0.32256196 | 0.32256195 | 0.32256086 | 0.322452 | 0.31454793 |
# | 2 | 0.15410216 | 0.15410242 | 0.1541024 | 0.15410083 | 0.15395866 | 0.1780069 |
# | 4 | 0.15339937 | 0.1533999 | 0.15339981 | 0.15339054 | 0.15279627 | 0.16415183 |
# | 8 | 0.37165765 | 0.37157061 | 0.36230361 | 0.20097386 | 0.19851114 | 0.16157953 |
# | 16 | 10.15891282 | 9.9185238 | 4.78231963 | 1.80889264 | 1.2692058 | 0.5120342 |
#
#
#
# Test Squared error table for Size = 200
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.27375297 | 0.27375324 | 0.27375323 | 0.27375292 | 0.27372139 | 0.27103148 |
# | 2 | 0.15108621 | 0.15108664 | 0.15108663 | 0.15108532 | 0.15095763 | 0.15240092 |
# | 4 | 0.14784916 | 0.14784995 | 0.14784989 | 0.1478426 | 0.14717959 | 0.14502231 |
# | 8 | 0.15371447 | 0.15374537 | 0.15372544 | 0.15213365 | 0.12473222 | 0.12469992 |
# | 16 | 0.00968021 | 0.00522544 | 0.1000335 | 0.02188789 | 0.03229064 | 0.0693897 |
#
#
#
# Test Squared error table for Size = 1000
#
# | Degree/Lambda | 1e-09 | 1e-07 | 1e-05 | 0.001 | 0.1 | 10.0 |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | 1 | 0.25612199 | 0.25612169 | 0.25612169 | 0.25612168 | 0.25612136 | 0.25609075 |
# | 2 | 0.14173117 | 0.14173206 | 0.14173208 | 0.14173207 | 0.14173167 | 0.14217415 |
# | 4 | 0.12898404 | 0.12898335 | 0.12898335 | 0.12898342 | 0.12899101 | 0.1308012 |
# | 8 | 0.08638591 | 0.08637336 | 0.0863737 | 0.08637293 | 0.08565101 | 0.10007603 |
# | 16 | 196.74841748 | 8.024e-05 | 2.092e-05 | 0.00107458 | 0.00744427 | 0.02854596 |
#
#
#
# Observations :
#
# 1: The train and test errors were obtained for different sizes, degrees of polynomials and different values of regularization parameters and have been given above
#
#
# 2 : For Size = 50 , minimum test error was obtained for degree = 4 , lambda = 0.1
#
# 3:  For Size = 100 , minimum test error was obtained for degree = 4 , lambda = 0.1
#
# 4:  For Size = 200 , minimum test error was obtained for degree = 16 , lambda = 1e-7
#
# 5:  For Size = 1000 , minimum test error was obtained for degree = 16 , lambda = 1e-5
#
# 6:  For sizes = 50 and 100 , the data seemed to overfit for degree = 16 and gave large test errors
#
# 7:  Also the data seemed to overfit for l=1e-9 and large sizes for degree = 16
